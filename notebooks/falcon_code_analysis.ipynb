# %% [markdown]
# # Analyzing the FalconCode dataset

# %%
# !pip3 install html2text
# Out:
# ...
#
# [notice] A new release of pip available: 22.3 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install openai

# %%
import pandas as pd
import numpy as np

import html2text

# %%
openai.api_key = "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"
[key.id for key in openai.Model.list().data]
# Out:
# ['babbage',
#  'text-davinci-003',
#  'davinci',
#  'text-davinci-edit-001',
#  'babbage-code-search-code',
#  'text-similarity-babbage-001',
#  'code-davinci-edit-001',
#  'text-davinci-001',
#  'ada',
#  'babbage-code-search-text',
#  'babbage-similarity',
#  'gpt-3.5-turbo-16k-0613',
#  'code-search-babbage-text-001',
#  'text-curie-001',
#  'gpt-3.5-turbo-0301',
#  'gpt-3.5-turbo-16k',
#  'code-search-babbage-code-001',
#  'text-ada-001',
#  'text-similarity-ada-001',
#  'text-davinci-002',
#  'curie-instruct-beta',
#  'ada-code-search-code',
#  'ada-similarity',
#  'code-search-ada-text-001',
#  'text-search-ada-query-001',
#  'davinci-search-document',
#  'ada-code-search-text',
#  'text-search-ada-doc-001',
#  'davinci-instruct-beta',
#  'text-similarity-curie-001',
#  'code-search-ada-code-001',
#  'ada-search-query',
#  'text-search-davinci-query-001',
#  'curie-search-query',
#  'davinci-search-query',
#  'babbage-search-document',
#  'ada-search-document',
# ...

# %%
local_dir = "/Users/xrw/Desktop/"
path = local_dir+"falconcode/falconcode_v1_table_problems.csv"

problems_df = pd.read_csv(path)
# problems_df.columns
len(problems_df['id'].unique())
# Out:
# 422

# %%
path = local_dir+"falconcode/falconcode_v1_table_runs.csv"
runs_df = pd.read_csv(path)

# %%
path = local_dir+"falconcode/falconcode_v1_code_samples.csv"
samples_df = pd.read_csv(path)
# rename column hash to code_hash for easier mearge in the next steps
samples_df.rename(columns={'hash': 'code_hash'}, inplace=True)

# %%
merged_df = pd.merge(runs_df, samples_df, on='code_hash')
merged_df = merged_df[['problem_id', 'source_code']].drop_duplicates(subset='problem_id', keep='first')

# %%
merged_df = merged_df.reset_index()

# %%
for i in range(len(merged_df)):
    row = merged_df.iloc[i]
    print(row['source_code'])
# Out:
# # Project Part 2 - Recon
# # REDACTED_NAME(S)
# # Course: CS110, Fall 2021
# # DOCUMENTATION: C4C REDACTED_USER_2921 and C4C REDACTED_USER_87 helped me in the squadron 12 academic room with
# # understanding the set up for the lab, including how to scan, the radius of the scan to aid with my scan pattern,
# # and assigning get_scan_results to a variable to save the information as a list. Additionally, I referenced my sky_writer
# # code as a template for this scan code. C4C REDACTED_USER_2921 helped walk me through the logic of how to use a function to get
# # needed information to use in the drone one function.
#
# import random
# # AUTOGRADER IMPORT REMOVED
# from drone_api import set_destination
# from drone_api import smoke_on
# from drone_api import smoke_off
# from drone_api import get_x_location
# from drone_api import get_y_location
# from drone_api import destination_reached
# from drone_api import taking_off
# from drone_api import mission_complete
# ...

# %%
runs_df['score'].unique()
# Out:
# array([ -1,   0, 100,   5,  33,  50,  60,  20,  40,  14,  95,  10,  67,
#         66,   4,  55,  52,  90,  63,  45,  27,   9,  56,  15,  25,  80,
#         58,  68,  62,  84,  75,  16,  42,  28,  94,  30,  86,  57,  59,
#         35,  69,  85,  92,  71,  73,  76,  81,  13,  72,  19,  39,  24,
#         37,   7,  53,  77,  70,  11,  17,  88,  31,  48,   8,  26,   1,
#         21,  54,  61,   6,  46,  38,  12,  87,  93,  32,  79,  83,  34,
#         41,  91,  44,  22,  18,  36,  49,  29,   2,  65,  82,  47,  64,
#         78,   3,  99,  97,  74,  43, 102,  98,  23,  51,  89,  96])

# %%
runs_df = runs_df[runs_df['score']!=-1]
runs_df
# Out:
#               id                            student_id  course_id  \
# 3              4  8e6da047-045a-4be3-ac88-f08854f793ef          3
# 5              6  14ef3028-bbf0-491c-b18c-a7af53561656          3
# 14            15  4d702d86-fa68-43cf-ba54-d6c5ba1fb7ea          3
# 16            17  4d702d86-fa68-43cf-ba54-d6c5ba1fb7ea          3
# 18            19  4d702d86-fa68-43cf-ba54-d6c5ba1fb7ea          3
# ...          ...                                   ...        ...
# 1433318  1433319  8a9837cb-a545-4eaa-90b0-d7e37caeadb2          2
# 1433319  1433320  8a9837cb-a545-4eaa-90b0-d7e37caeadb2          2
# 1433320  1433321  8a9837cb-a545-4eaa-90b0-d7e37caeadb2          2
# 1433321  1433322  8a9837cb-a545-4eaa-90b0-d7e37caeadb2          2
# 1433322  1433323  8a9837cb-a545-4eaa-90b0-d7e37caeadb2          2
#
#                         problem_id            timestamp  score  \
# 3                            Recon  2021-12-24 23:02:47      0
# ...

# %%
average_scores = runs_df.groupby('problem_id')['score'].mean()
print(average_scores)
# Out:
# problem_id
# Airstrike          0.000000
# CAESAR             0.000000
# Caesar_gc          0.000000
# FileIO_echo       21.677588
# FileIO_runways    15.940860
#                     ...
# pex1              47.547568
# pex2               0.117021
# pex2_gc            1.146199
# pex3               0.000000
# skywriter          0.000000
# Name: score, Length: 469, dtype: float64

# %%
runs_df[runs_df['problem_id']=="Airstrike"]
# Out:
#           id                            student_id  course_id problem_id  \
# 568      569  c065d2dc-9f6c-4c45-a4d5-acc5e411cb8c          3  Airstrike
# 575      576  7e607c1d-0bd9-47b7-a561-66d619ac5d8a          3  Airstrike
# 576      577  7e607c1d-0bd9-47b7-a561-66d619ac5d8a          3  Airstrike
# 1180    1181  8829ca37-e32f-4636-a5b0-d87b90dd8f12          3  Airstrike
# 1198    1199  8805e789-7882-4877-b9cf-ad85f453a562          3  Airstrike
# ...      ...                                   ...        ...        ...
# 76510  76511  07c00109-f0fc-48e5-b18a-2092d964747b          3  Airstrike
# 76534  76535  07c00109-f0fc-48e5-b18a-2092d964747b          3  Airstrike
# 76546  76547  7cd4cefc-0261-474e-bc74-d80bee388a65          3  Airstrike
# 76566  76567  f3ce18d2-9982-4ef7-b32c-6b9492d5bd75          3  Airstrike
# 76673  76674  16b8c2b3-34d9-4a81-8625-cd5036335cb9          3  Airstrike
#
#                  timestamp  score                                 code_hash
# ...

# %%
def getConcepts(problem_id, df):
    """ 
        return a list of concepts that required for solving this problem 
    """
    concept_list = ['input_str', 'input_cast', 'output', 'assignment', 'conditional',
       'function_call', 'function_def', 'function_return', 'loop_counting',
       'loop_until', 'loop_elements', 'loop_nested', 'stat_calculate',
       'file_read', 'file_write', 'list', 'list_2d', 'dictionary', 'item_set',
       'tuple']
    return [concept for concept in concept_list if (df[df['id']==problem_id][concept].iloc[0]==1)]

# %%
def generatePropmt(problem_description, skeleton_code, student_code, concepts):
    
    prompt = "You are a helpful Teaching Assistant in a CS1 programming course teaching the basics of python programming. Below is a problem description, as well as a student's attempt at that problem which is incorrect. Provide a solution to this incorrect program which is as close as possible to this buggy program" 
    
    prompt += f"{prompt} \nProblem description:\n{problem_description}\n"
    
    if skeleton_code:
        prompot += f"{prompt} \nPlease build your solution based on the following skeleton code: :\n{skeleton_code}\n"
        
    if concepts:
        prompt +=  f"Assume your python knowledge is within {str(concepts)}\n"
    prompt += "The answer should be code only, please do not provide explanations. Please put the answer within the fenced code block. "

    return prompt

# %%
def extractResultCode(raw_result):
    """
    cleaning the generated code format
    """
    if raw_result[:9] == "```python":
        raw_result = raw_result.split("```python")[1]
    if raw_result[-3:] == "```":
        raw_result = raw_result.split("```")[0]
    return raw_result

# %%
def generateGPTAnswer(prompt, api_key="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", model="gpt-4"):
    """
    input: prompt, problem_description, student_code
    output: gpt-genrated code
    """
    openai.api_key = api_key
    
    response = openai.ChatCompletion.create(
      model=model,
      messages=[
        {"role": "user", 
         "content": prompt
        }
      ]
    )
    
    gpt_code = response["choices"][0]['message']['content']
    return gpt_code

# %%
 """
looping over all problems
"""
problem_ids = []
prompts = []
codes = []
for i in range(10):
# for i in range(len(problems_df)):
    print(i)
    row = problems_df.iloc[i]
    problem_description = html2text.html2text(row['prompt'])
    prompt = generatePropmt(problem_description, "", concepts=[])
    code = extractResultCode(generateGPTAnswer(prompt, model="gpt-4"))
        
    problem_ids.append(row['id'])
    prompts.append(prompt)
    codes.append(code)
    
result_df = pd.DataFrame({"problem_id":problem_ids, "prompts": prompts, "code": codes})
result_filename = os.path.join(args.output_dir, 'result.csv')
result_df.to_csv(result_filename)
# Out:
# 0
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-178-e78997c44ad0> in <module>
#      11    problem_description = html2text.html2text(row['prompt'])
#      12    prompt = generatePropmt(problem_description, "", concepts=[])
# ---> 13    code = extractResultCode(generateGPTAnswer(prompt, model="gpt-4"))
#      14
#      15    problem_ids.append(row['id'])
#
# <ipython-input-177-8c57e37afada> in generateGPTAnswer(prompt, api_key, model)
#       6     openai.api_key = api_key
#       7
# ----> 8     response = openai.ChatCompletion.create(
#       9       model=model,
#      10       messages=[
#
# ~/opt/anaconda3/lib/python3.8/site-packages/openai/api_resources/chat_completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
# ...

# %%
result_df = pd.DataFrame({"problem_id":list(merged_df['id'][:562]), "prompts": prompts, "GPT3.5_generated_code": codes})

# %%
result_df.to_csv("/Users/xrw/Desktop/result.csv")
